# %% [markdown]
# # Text file lemmatizer

# %% [markdown]
# ### Installing requirements

# %%
# !pip install -r requirement.txt
# Out:
# Requirement already satisfied: attrs==19.3.0 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 1)) (19.3.0)
# Requirement already satisfied: backcall==0.2.0 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 2)) (0.2.0)
# Requirement already satisfied: bleach==3.1.5 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 3)) (3.1.5)
# Requirement already satisfied: certifi==2020.6.20 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 4)) (2020.6.20)
# Requirement already satisfied: click==7.1.2 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 5)) (7.1.2)
# Requirement already satisfied: decorator==4.4.2 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 6)) (4.4.2)
# Requirement already satisfied: defusedxml==0.6.0 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 7)) (0.6.0)
# Requirement already satisfied: entrypoints==0.3 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 8)) (0.3)
# Requirement already satisfied: importlib-metadata==1.7.0 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 9)) (1.7.0)
# Requirement already satisfied: ipykernel==5.3.0 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 10)) (5.3.0)
# Requirement already satisfied: ipython==7.16.1 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 11)) (7.16.1)
# Requirement already satisfied: ipython-genutils==0.2.0 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 12)) (0.2.0)
# Requirement already satisfied: ipywidgets==7.5.1 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 13)) (7.5.1)
# Requirement already satisfied: jedi==0.17.1 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 14)) (0.17.1)
# Requirement already satisfied: Jinja2==2.11.2 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 15)) (2.11.2)
# Requirement already satisfied: joblib==0.16.0 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 16)) (0.16.0)
# Requirement already satisfied: jsonschema==3.2.0 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 17)) (3.2.0)
# Requirement already satisfied: jupyter==1.0.0 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 18)) (1.0.0)
# Requirement already satisfied: jupyter-client==6.1.5 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 19)) (6.1.5)
# Requirement already satisfied: jupyter-console==6.1.0 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 20)) (6.1.0)
# Requirement already satisfied: jupyter-core==4.6.3 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 21)) (4.6.3)
# Requirement already satisfied: MarkupSafe==1.1.1 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 22)) (1.1.1)
# Requirement already satisfied: mistune==0.8.4 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 23)) (0.8.4)
# Requirement already satisfied: nbconvert==5.6.1 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 24)) (5.6.1)
# Requirement already satisfied: nbformat==5.0.7 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 25)) (5.0.7)
# Requirement already satisfied: nltk==3.5 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 26)) (3.5)
# Requirement already satisfied: notebook==6.0.3 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 27)) (6.0.3)
# Requirement already satisfied: numpy==1.19.0 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 28)) (1.19.0)
# Requirement already satisfied: packaging==20.4 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 29)) (20.4)
# Requirement already satisfied: pandas==1.0.5 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 30)) (1.0.5)
# Requirement already satisfied: pandocfilters==1.4.2 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 31)) (1.4.2)
# Requirement already satisfied: parso==0.7.0 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 32)) (0.7.0)
# Requirement already satisfied: pexpect==4.8.0 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 33)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 34)) (0.7.5)
# Requirement already satisfied: prometheus-client==0.8.0 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 35)) (0.8.0)
# Requirement already satisfied: prompt-toolkit==3.0.5 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 36)) (3.0.5)
# Requirement already satisfied: ptyprocess==0.6.0 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 37)) (0.6.0)
# Requirement already satisfied: Pygments==2.6.1 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 38)) (2.6.1)
# Requirement already satisfied: pyparsing==2.4.7 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 39)) (2.4.7)
# Requirement already satisfied: pyrsistent==0.16.0 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 40)) (0.16.0)
# Requirement already satisfied: python-dateutil==2.8.1 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 41)) (2.8.1)
# Requirement already satisfied: pytz==2020.1 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 42)) (2020.1)
# Requirement already satisfied: pywsd==1.2.4 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 43)) (1.2.4)
# Requirement already satisfied: pyzmq==19.0.1 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 44)) (19.0.1)
# Requirement already satisfied: qtconsole==4.7.5 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 45)) (4.7.5)
# Requirement already satisfied: QtPy==1.9.0 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 46)) (1.9.0)
# Requirement already satisfied: regex==2020.6.8 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 47)) (2020.6.8)
# Requirement already satisfied: Send2Trash==1.5.0 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 48)) (1.5.0)
# Requirement already satisfied: six==1.15.0 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 49)) (1.15.0)
# Requirement already satisfied: terminado==0.8.3 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 50)) (0.8.3)
# Requirement already satisfied: testpath==0.4.4 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 51)) (0.4.4)
# Requirement already satisfied: tornado==6.0.4 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 52)) (6.0.4)
# Requirement already satisfied: tqdm==4.47.0 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 53)) (4.47.0)
# Requirement already satisfied: traitlets==4.3.3 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 54)) (4.3.3)
# Requirement already satisfied: wcwidth==0.2.5 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 55)) (0.2.5)
# Requirement already satisfied: webencodings==0.5.1 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 56)) (0.5.1)
# Requirement already satisfied: widgetsnbextension==3.5.1 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 57)) (3.5.1)
# Requirement already satisfied: wn==0.0.23 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 58)) (0.0.23)
# Requirement already satisfied: zipp==3.1.0 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from -r requirement.txt (line 59)) (3.1.0)
# Requirement already satisfied: setuptools>=18.5 in /home/tra/miniconda3/envs/nltklearn/lib/python3.7/site-packages (from ipython==7.16.1->-r requirement.txt (line 11)) (47.3.1.post20200622)

# %% [markdown]
# ### Dictionary of contractions

# %%
contractions_dict = {     
"ain't": "am not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he had",
"he'd've": "he would have",
"he'll": "he will",
"he'll've": "he will have",
"he's": "he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how is",
"I'd": "I had",
"I'd've": "I would have",
"I'll": "I will",
"I'll've": "I will have",
"I'm": "I am",
"I've": "I have",
"isn't": "is not",
"it'd": "it had",
"it'd've": "it would have",
"it'll": "it will",
"it'll've": "iit will have",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she had",
"she'd've": "she would have",
"she'll": "she will",
"she'll've": "she will have",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so is",
"that'd": "that had",
"that'd've": "that would have",
"that's": "that is",
"there'd": "there had",
"there'd've": "there would have",
"there's": "there is",
"they'd": "they had",
"they'd've": "they would have",
"they'll": "they will",
"they'll've": "they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we had",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what'll've": "what will have",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"when's": "when is",
"when've": "when have",
"where'd": "where did",
"where's": "where is",
"where've": "where have",
"who'll": "who will",
"who'll've": "who will have",
"who's": "who is",
"who've": "who have",
"why's": "why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you had",
"you'd've": "you would have",
"you'll": "you will",
"you'll've": "you will have",
"you're": "you are",
"you've": "you have",
"Ain't": "am not",
"Aren't": "are not",
"Can't": "cannot",
"Can't've": "cannot have",
"'Cause": "because",
"Could've": "could have",
"Couldn't": "could not",
"Couldn't've": "could not have",
"Didn't": "did not",
"Doesn't": "does not",
"Don't": "do not",
"Hadn't": "had not",
"Hadn't've": "had not have",
"Hasn't": "has not",
"Haven't": "have not",
"He'd": "he had",
"He'd've": "he would have",
"He'll": "he will",
"He'll've": "he will have",
"He's": "he is",
"How'd": "how did",
"How'd'y": "how do you",
"How'll": "how will",
"How's": "how is",
"Isn't": "is not",
"It'd": "it had",
"It'd've": "it would have",
"It'll": "it will",
"It'll've": "iit will have",
"It's": "it is",
"Let's": "let us",
"Ma'am": "madam",
"Mayn't": "may not",
"Might've": "might have",
"Mightn't": "might not",
"Mightn't've": "might not have",
"Must've": "must have",
"Mustn't": "must not",
"Mustn't've": "must not have",
"Needn't": "need not",
"Needn't've": "need not have",
"Oughtn't": "ought not",
"Oughtn't've": "ought not have",
"Shan't": "shall not",
"Sha'n't": "shall not",
"Shan't've": "shall not have",
"She'd": "she had",
"She'd've": "she would have",
"She'll": "she will",
"She'll've": "she will have",
"She's": "she is",
"Should've": "should have",
"Shouldn't": "should not",
"Shouldn't've": "should not have",
"So've": "so have",
"So's": "so is",
"That'd": "that had",
"That'd've": "that would have",
"That's": "that is",
"There'd": "there had",
"There'd've": "there would have",
"There's": "there is",
"They'd": "they had",
"They'd've": "they would have",
"They'll": "they will",
"They'll've": "they will have",
"They're": "they are",
"They've": "they have",
"To've": "to have",
"Wasn't": "was not",
"We'd": "we had",
"We'd've": "we would have",
"We'll": "we will",
"We'll've": "we will have",
"We're": "we are",
"We've": "we have",
"Weren't": "were not",
"What'll": "what will",
"What'll've": "what will have",
"What're": "what are",
"What's": "what is",
"What've": "what have",
"When's": "when is",
"When've": "when have",
"Where'd": "where did",
"Where's": "where is",
"Where've": "where have",
"Who'll": "who will",
"Who'll've": "who will have",
"Who's": "who is",
"Who've": "who have",
"Why's": "why is",
"Why've": "why have",
"Will've": "will have",
"Won't": "will not",
"Won't've": "will not have",
"Would've": "would have",
"Wouldn't": "would not",
"Wouldn't've": "would not have",
"Y'all": "you all",
"Y'all'd": "you all would",
"Y'all'd've": "you all would have",
"Y'all're": "you all are",
"Y'all've": "you all have",
"You'd": "you had",
"You'd've": "you would have",
"You'll": "you will",
"You'll've": "you will have",
"You're": "you are",
"You've": "you have"

}

# %% [markdown]
# ### lemmatizing

# %%
import string
import re
import nltk
from string import punctuation
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

lemmatizer = WordNetLemmatizer()


input_file = "input.txt"

def read_input(input_file):
    with open (input_file,"r+", encoding="utf-8") as fin:
        return fin.read()
input_file = "input.txt"

def read_input(input_file):
    with open (input_file,"r+", encoding="utf-8") as fin:
        return fin.read()

get_text = read_input(input_file)
#print(get_text)
#print("\n")

get_text = get_text.split(" ")
if len(get_text) > 200:
    start = (len(get_text)-200)//2
    end = len(get_text) - start
    #print(start)
    #print(end)
    middle = get_text[start:end]

else:
    middle = get_text

text_list = middle
#print(text_list)
text = " "
text = text.join(text_list)

def expand_contractions(text, contractions_dict):
    contractions_pattern = re.compile('({})'.format('|'.join(contractions_dict.keys())),
                                      flags=re.IGNORECASE | re.DOTALL)

    def expand_match(contraction):
        match = contraction.group(0)
        first_char = match[0]
        expanded_contraction = contractions_dict.get(match) \
            if contractions_dict.get(match) \
            else contractions_dict.get(match.lower())
        expanded_contraction = expanded_contraction
        return expanded_contraction

    expanded_text = contractions_pattern.sub(expand_match, text)
    expanded_text = re.sub("'", "", expanded_text)
    return expanded_text

text = expand_contractions(text,contractions_dict)
#print(text)
#print("\n")

def remove_punct(text):
    """
    take string input and clean string without punctuations.
    use regex to remove the punctuations.
    """
    return ''.join(c for c in text if c not in punctuation)

text = remove_punct(text)
#print(text)
#print("\n")

lemmatizer = WordNetLemmatizer()

# function to convert nltk tag to wordnet tag
def nltk_tag_to_wordnet_tag(nltk_tag):
    if nltk_tag.startswith('J'):
        return wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return wordnet.VERB
    elif nltk_tag.startswith('N'):
        return wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return wordnet.ADV
    else:          
        return None

def lemmatize_sentence(sentence):
    #tokenize the sentence and find the POS tag for each token
    nltk_tagged = nltk.pos_tag(nltk.word_tokenize(sentence))  
    #tuple of (token, wordnet_tag)
    wordnet_tagged = map(lambda x: (x[0], nltk_tag_to_wordnet_tag(x[1])), nltk_tagged)
    lemmatized_sentence = []
    for word, tag in wordnet_tagged:
        if tag is None:
            #if there is no available tag, append the token as is
            lemmatized_sentence.append(word)
        else:        
            #else use the tag to lemmatize the token
            lemmatized_sentence.append(lemmatizer.lemmatize(word, tag))
    return " ".join(lemmatized_sentence)

lemm = lemmatize_sentence(text)

with open('output.txt', 'w') as f:
    for item in lemm:
        f.write("%s" % item)

# %% [markdown]
# ### words count check in text file

# %%
fname = input("Enter file name: ")
 
num_words = 0
 
with open(fname, 'r') as f:
    for line in f:
        words = line.split()
        num_words += len(words)
print("Number of words:")
print(num_words)
# Out:
# Enter file name: output.txt
# Number of words:
# 214
